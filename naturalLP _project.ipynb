# %%
from tika import parser
import nltk
import matplotlib.pyplot as plt
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from nltk.text import Text
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re

# %%
raw = parser.from_file('D:\\pythonbasics\\entkingdom.pdf')

# %%
data = raw['content']

# %%
data_1 = re.sub('[^a-zA-Z]',' ',data)

# %%
data = data_1.lower()

# %%
print(data)
# Out:
#                                   kingdom of a thousand       eftos ent   kingdom of a thousand better read something else   first without the central word  absolute   eftos ent     kingdom of a thousand  eftos epos  en premier  eftos is no author  eftos owns the kingdom of a thousand    due  to  bankruptcy  of  the  genre eftos  started  to write  his  own  sci fi  saga  unlike  the  opposition   eftos  intentionally  uses  no  voodoo  like  time  machines  beings of light or prophecies  these facts led to the original creation of the   tunnel sci fi trilogy  eftos epos  kingdom of a thousand   this trilogy is a science fiction saga consisting of the following original  books     i  kingdom of a thousand  ii  halfworld  iii  the last crisis   it  tells  the adventures of  three friends  prince henley to westerburg   patchara petch a boon and svinenysh galactic  the  story  takes  place                     net  mediantime  in  the  kingdom of a thousand  each book consists of the adv
# ...

# %%
print(word_tokenize(data))
# Out:
# ['kingdom', 'of', 'a', 'thousand', 'eftos', 'ent', 'kingdom', 'of', 'a', 'thousand', 'better', 'read', 'something', 'else', 'first', 'without', 'the', 'central', 'word', 'absolute', 'eftos', 'ent', 'kingdom', 'of', 'a', 'thousand', 'eftos', 'epos', 'en', 'premier', 'eftos', 'is', 'no', 'author', 'eftos', 'owns', 'the', 'kingdom', 'of', 'a', 'thousand', 'due', 'to', 'bankruptcy', 'of', 'the', 'genre', 'eftos', 'started', 'to', 'write', 'his', 'own', 'sci', 'fi', 'saga', 'unlike', 'the', 'opposition', 'eftos', 'intentionally', 'uses', 'no', 'voodoo', 'like', 'time', 'machines', 'beings', 'of', 'light', 'or', 'prophecies', 'these', 'facts', 'led', 'to', 'the', 'original', 'creation', 'of', 'the', 'tunnel', 'sci', 'fi', 'trilogy', 'eftos', 'epos', 'kingdom', 'of', 'a', 'thousand', 'this', 'trilogy', 'is', 'a', 'science', 'fiction', 'saga', 'consisting', 'of', 'the', 'following', 'original', 'books', 'i', 'kingdom', 'of', 'a', 'thousand', 'ii', 'halfworld', 'iii', 'the', 'last', 'crisis',
# ...

# %%
print(len(word_tokenize(data)))
# Out:
# 50942

# %%
print(len(sent_tokenize(data)))
# Out:
# 1

# %%
from nltk.corpus import stopwords
data1= data

stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'am', 'can', 'have', 'our', "wasn't", 'your', 'be', 'won', 'into', "couldn't", 'mustn', 'hadn', 'few', 'at', 'until', 'these', 'being', "shouldn't", 'll', 'their', 'above', 'on', 'after', 'nor', 'its', 'did', 'ourselves', 'such', 'for', 'yourself', 'is', 'his', "doesn't", 't', 'when', 'because', 'through', 'over', 'just', 'himself', 'y', 'own', 'had', 'down', 'about', 'been', 'itself', 'in', 'themselves', 'having', 's', 'if', 'my', 'him', "needn't", 'and', 'both', 'the', 'didn', 'we', 'out', 'against', 'was', 'under', 'ain', 'shouldn', 'what', 'should', 'd', 'no', 'ours', 'her', 'or', 'do', "weren't", 'here', 'where', 'how', 'than', 'hasn', "haven't", 'who', 'were', 'there', 'each', 'those', 'are', 'below', 'this', 'any', 've', "you're", 'again', 're', "aren't", "don't", 'herself', 'wouldn', 'from', 'now', "didn't", "it's", 'whom', 'of', 'why', 'isn', "won't", 'o', 'haven', 'mightn', 'she', 'hers', 'shan', 'i', 'up', 'only', "that'll", 'wasn', 'too', 'will', 'm', 'before', 'which', 
# ...

# %%
word_tokens = word_tokenize(data1)

filtered_sentence = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

#print(word_tokens)
print(filtered_sentence)
# Out:
# ['kingdom', 'thousand', 'eftos', 'ent', 'kingdom', 'thousand', 'better', 'read', 'something', 'else', 'first', 'without', 'central', 'word', 'absolute', 'eftos', 'ent', 'kingdom', 'thousand', 'eftos', 'epos', 'en', 'premier', 'eftos', 'author', 'eftos', 'owns', 'kingdom', 'thousand', 'due', 'bankruptcy', 'genre', 'eftos', 'started', 'write', 'sci', 'fi', 'saga', 'unlike', 'opposition', 'eftos', 'intentionally', 'uses', 'voodoo', 'like', 'time', 'machines', 'beings', 'light', 'prophecies', 'facts', 'led', 'original', 'creation', 'tunnel', 'sci', 'fi', 'trilogy', 'eftos', 'epos', 'kingdom', 'thousand', 'trilogy', 'science', 'fiction', 'saga', 'consisting', 'following', 'original', 'books', 'kingdom', 'thousand', 'ii', 'halfworld', 'iii', 'last', 'crisis', 'tells', 'adventures', 'three', 'friends', 'prince', 'henley', 'westerburg', 'patchara', 'petch', 'boon', 'svinenysh', 'galactic', 'story', 'takes', 'place', 'net', 'mediantime', 'kingdom', 'thousand', 'book', 'consists', 'adventures'
# ...

# %%
len(filtered_sentence)
# Out:
# 27274

# %%
from nltk.text import Text

stop_words = nltk.corpus.stopwords.words('english')
newStopWords = ['.', '?', ",","however","even","iv","","’","however","fi","see","yet","a","s","i","dr","r","one","therefore","h","inbox","even","like","also","’","by","but","(",")","else","``","''",":","The","I","!","He","time","us","It","This","also","looks","i","...","In","You","like","A","back","Then","says","But","What","new","already","we","around","She","two","three","We","young","go","still","see","look","good","little","well","yes","system","know","right","something","immediately","head","immediately","would","much","much","us","takes","must","come","comm","exactly","next","without","almost","asks","years","however","years","however","best","behind","last","later","times","goes","quickly","take","general","oh","get","possible","continues","i'm","everything","said","could","altough","dear","home","soon","since","say","long","different"]
stop_words.extend(newStopWords)
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
word_tokens = word_tokenize(data1)

filtered_sentence2 = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence2.append(w)

#print(word_tokens)
print(filtered_sentence2)
# Out:
# ['kingdom', 'thousand', 'eftos', 'ent', 'kingdom', 'thousand', 'better', 'read', 'first', 'central', 'word', 'absolute', 'eftos', 'ent', 'kingdom', 'thousand', 'eftos', 'epos', 'en', 'premier', 'eftos', 'author', 'eftos', 'owns', 'kingdom', 'thousand', 'due', 'bankruptcy', 'genre', 'eftos', 'started', 'write', 'sci', 'saga', 'unlike', 'opposition', 'eftos', 'intentionally', 'uses', 'voodoo', 'machines', 'beings', 'light', 'prophecies', 'facts', 'led', 'original', 'creation', 'tunnel', 'sci', 'trilogy', 'eftos', 'epos', 'kingdom', 'thousand', 'trilogy', 'science', 'fiction', 'saga', 'consisting', 'following', 'original', 'books', 'kingdom', 'thousand', 'ii', 'halfworld', 'iii', 'crisis', 'tells', 'adventures', 'friends', 'prince', 'henley', 'westerburg', 'patchara', 'petch', 'boon', 'svinenysh', 'galactic', 'story', 'place', 'net', 'mediantime', 'kingdom', 'thousand', 'book', 'consists', 'adventures', 'children', 'embedded', 'futuristic', 'sci', 'world', 'old', 'reason', 'book', 'come
# ...

# %%
print(len(filtered_sentence2))
# Out:
# 22855

# %%
freq=nltk.FreqDist(filtered_sentence2)
freq
# Out:
# FreqDist({'henley': 311, 'patchara': 201, 'svinenysh': 155, 'first': 118, 'rebelkov': 95, 'ruba': 91, 'old': 70, 'exa': 64, 'svin': 64, 'nef': 62, ...})

# %%
import matplotlib.pyplot as plt
freq.plot(35,cumulative=False)

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()
for w in filtered_sentence2:
    print(ps.stem(w))
# Out:
# kingdom
# thousand
# efto
# ent
# kingdom
# thousand
# better
# read
# first
# central
# word
# absolut
# efto
# ent
# kingdom
# thousand
# efto
# epo
# en
# premier
# efto
# author
# efto
# own
# kingdom
# thousand
# due
# bankruptci
# genr
# efto
# start
# write
# sci
# saga
# unlik
# opposit
# efto
# intent
# use
# voodoo
# machin
# be
# light
# propheci
# fact
# led
# origin
# creation
# tunnel
# sci
# trilog
# efto
# epo
# kingdom
# thousand
# trilog
# scienc
# fiction
# saga
# consist
# follow
# origin
# book
# kingdom
# thousand
# ii
# halfworld
# iii
# crisi
# tell
# adventur
# friend
# princ
# henley
# westerburg
# patchara
# petch
# boon
# svinenysh
# galact
# stori
# place
# net
# mediantim
# kingdom
# thousand
# book
# consist
# adventur
# children
# embed
# futurist
# sci
# world
# old
# reason
# book
# come
# youth
# adultedit
# certain
# sci
# detail
# mention
# book
# man
# kingdom
# thousand
# world
# first
# sci
# epo
# kingdom
# thousand
# charact
# name
# place
# ...

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()


for word in filtered_sentence2:
    print(lemmatizer.lemmatize(word))
# Out:
# kingdom
# thousand
# eftos
# ent
# kingdom
# thousand
# better
# read
# first
# central
# word
# absolute
# eftos
# ent
# kingdom
# thousand
# eftos
# epos
# en
# premier
# eftos
# author
# eftos
# owns
# kingdom
# thousand
# due
# bankruptcy
# genre
# eftos
# started
# write
# sci
# saga
# unlike
# opposition
# eftos
# intentionally
# us
# voodoo
# machine
# being
# light
# prophecy
# fact
# led
# original
# creation
# tunnel
# sci
# trilogy
# eftos
# epos
# kingdom
# thousand
# trilogy
# science
# fiction
# saga
# consisting
# following
# original
# book
# kingdom
# thousand
# ii
# halfworld
# iii
# crisis
# tell
# adventure
# friend
# prince
# henley
# westerburg
# patchara
# petch
# boon
# svinenysh
# galactic
# story
# place
# net
# mediantime
# kingdom
# thousand
# book
# consists
# adventure
# child
# embedded
# futuristic
# sci
# world
# old
# reason
# book
# come
# youth
# adultedition
# certain
# sci
# detail
# mentioned
# book
# man
# kingdom
# thousand
# world
# first
# ...

# %%
print(freq_words)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-fd9131b57eef> in <module>
# ----> 1 print(freq_words)
#
# NameError: name 'freq_words' is not defined
